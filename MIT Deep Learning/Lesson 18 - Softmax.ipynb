# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, datasets
import matplotlib.pyplot as plt

# Load and preprocess the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Define the model architecture
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Flatten 28x28 images to a 784-dimensional vector
    layers.Dense(128, activation='relu'),  # Fully connected layer with 128 units and ReLU activation
    layers.Dense(10, activation='softmax') # Output layer with 10 units (for 10 classes) and softmax activation
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=10, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")

# Plot training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1500/1500 [==============================] - 19s 11ms/step - loss: 0.2853 - accuracy: 0.9173 - val_loss: 0.1532 - val_accuracy: 0.9578
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1284 - accuracy: 0.9625 - val_loss: 0.1227 - val_accuracy: 0.9639
# Epoch 3/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0900 - accuracy: 0.9735 - val_loss: 0.1122 - val_accuracy: 0.9660
# Epoch 4/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0662 - accuracy: 0.9805 - val_loss: 0.0916 - val_accuracy: 0.9737
# Epoch 5/10
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0518 - accuracy: 0.9844 - val_loss: 0.0970 - val_accuracy: 0.9711
# Epoch 6/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0411 - accuracy: 0.9874 - val_loss: 0.0873 - val_accuracy: 0.9758
# Epoch 7/10
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0310 - accuracy: 0.9904 - val_loss: 0.0862 - val_accuracy: 0.9773
# Epoch 8/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0256 - accuracy: 0.9922 - val_loss: 0.0916 - val_accuracy: 0.9753
# Epoch 9/10
# 1500/1500 [==============================] - 8s 6ms/step - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.0914 - val_accuracy: 0.9770
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.0941 - val_accuracy: 0.9765
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0851 - accuracy: 0.9759
# Test accuracy: 0.9758999943733215

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Programming frameworks can not only shorten your coding time but sometimes also perform optimizations that speed up your code.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
